# %% [markdown]
# <a href="https://colab.research.google.com/github/Machine-Learning-Tokyo/DL-workshop-series/blob/master/Simple_GAN_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Imports

# %% [markdown]
# ### Function to build the generator

# %% [markdown]
# ### Function to build the discriminator

# %% [markdown]
# ### Function to compile the models

# %% [markdown]
# ### Function to sample and save generated images

# %% [markdown]
# ### Function to train the models

# %% [markdown]
# ### Define hyperparameters

# %% [markdown]
# ### Generate the models

# %% [markdown]
# ### Train the models

# %% [markdown]
# ### Display samples
